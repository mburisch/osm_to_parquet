# %%
import pandas as pd
import pyarrow.parquet as pq

table = pq.read_table("/tmp/osm/ways_01_000001.parquet")
print(table.schema)
df = table.to_pandas()
df
# Out:
# id: int64 not null
# tags: map<string ('keys'), string ('values') ('tags')>
#   child 0, tags: struct<keys: string not null, values: string> not null
#       child 0, keys: string not null
#       child 1, values: string
# nodes: list<item: int64>
#   child 0, item: int64
# version: int32
# timestamp: int64
# changeset: int64
# uid: int64
# user_sid: string
#               id                                               tags  \
# 0        4939011              [(source, PGS), (natural, coastline)]
# 1        4939181              [(source, PGS), (natural, coastline)]
# 2        4939184              [(natural, coastline), (source, PGS)]
# 3        4939194              [(natural, coastline), (source, PGS)]
# 4        4939198              [(natural, coastline), (source, PGS)]
# ...          ...                                                ...
# 510995  11309438  [(surface, asphalt), (tiger:county, Santa Rosa...
# 510996  11309439  [(tiger:zip_left, 32571), (tiger:cfcc, A41), (...
# ...
